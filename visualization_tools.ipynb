# %%
from visualization_utilities import *

# %%
data_path  = './input_data/JUNIPR_format_jets.dat'
model_path = './saved_models/JUNIPR_test_weights'

# %% [markdown]
# # Plot Jet Image

# %%
jet_i   = 6 # jet number in list of jets in data_path
savefig = None # path to where you want to save the figure
plot_jet_image(jet_i, data_path, savefig=savefig)

# %% [markdown]
# # Plot Jet Tree

# %%
jet_i   = 6 # jet number in list of jets in data_path
savefig = None # path to where you want to save the figure
# without probabilities
plot_jet_tree(jet_i, data_path, savefig = savefig, angle_scale_factor = 1, model_path_1 = None)

# %%
# with probabilities
plot_jet_tree(jet_i, data_path, savefig = savefig, angle_scale_factor = 1, model_path_1 = model_path)
# Out:
# Using SimpleRNN Network
